# %%
# %matplotlib inline
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import pytesseract

# %%
filename = 'data/ktp/cropped/sample1.jpg'
text = pytesseract.image_to_string(Image.open(filename))
text
# Out:
# '331707170bb1000e'

# %%
image = cv2.imread('data/ktp/cropped/sample1.jpg')
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # grayscale
_,thresh = cv2.threshold(gray,150,255,cv2.THRESH_BINARY_INV) # threshold
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
dilated = cv2.dilate(thresh,kernel,iterations = 13) # dilate
contours, hierarchy = cv2.findContours(dilated,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE) # get contours


idx =0
# for each contour found, draw a rectangle around it on original image
for contour in contours:

    idx += 1

    # get rectangle bounding contour
    [x,y,w,h] = cv2.boundingRect(contour)

#     # discard areas that are too large
#     if h>30 and w>30:
#         continue

#     # discard areas that are too small
#     if h<40 or w<40:
#         continue

    # draw rectangle around contour on original image
    #cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,255),2)

    roi = image[y:y + h, x:x + w]

    plt.imshow(roi);plt.show();

# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/71/5a/d7600cad26276d991feecb27f3627ae2d0ee89aa1e3065fa4f9f1f2defbc/pytesseract-0.2.6.tar.gz (169kB)
#     100% |████████████████████████████████| 174kB 504kB/s
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/prodwork/lib/python3.7/site-packages (from pytesseract) (5.4.1)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Stored in directory: /home/nunenuh/.cache/pip/wheels/d5/90/56/ab7b652592da86821293f7cadc1c554aa376a0d57ce414d0a0
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.2.6

# %%
def clean_up(image):
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # grayscale
    ret,thresh = cv2.threshold(gray,127,255,cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(1,1))
    dilated = cv2.dilate(thresh, kernel, iterations = 1) # dilate
    return thresh

def get_image_char(clean_img, minw=10, minh=10, notx=0, noty=0):
    images = []
    contours, hierarchy = cv2.findContours(clean_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    bbox_list = []
    bboxuf_list=[]
    for cnt in contours:
        x,y,w,h = cv2.boundingRect(cnt)
        
        if w>minw and h>minh and x!=notx and y!=noty:
            bbox = (x,y,w,h)
            bbox_list.append(bbox)
        else:
            bbox_uf = (x,y,w,h)
            bboxuf_list.append(bbox_uf)

    bbox_list = sorted(bbox_list)
    for bbox in bbox_list:
        x, y, w, h = bbox
        images.append(clean_img[y:y+h,x:x+w])
        
        
    imagesuf = []
    bboxuf_list = sorted(bboxuf_list)
    for bbox in bboxuf_list:
        x, y, w, h = bbox
        imagesuf.append(clean_img[y:y+h,x:x+w])
    return imagesuf

# %%
filename = 'data/ktp/cropped/sample6.jpg'
image = cv2.imread(filename)
clean_img = clean_up(image)
plt.imshow(clean_img, cmap='gray');plt.show()
images = get_image_char(clean_img)
for img in images:
    plt.imshow(img, cmap='gray');plt.show()

# %%
filename = 'data/ktp/cropped/sample1.jpg'
im = cv2.imread(filename)
text = pytesseract.image_to_string(Image.fromarray(img), lang="eng")
text
# Out:
# ''

# %%
im = cv2.imread(filename,0)
_,thresh = cv2.threshold(im,127,255,cv2.THRESH_BINARY) # threshold
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS,(1,1))
dilated = cv2.dilate(thresh,kernel,iterations = 1) # dilate
plt.imshow(thresh)
